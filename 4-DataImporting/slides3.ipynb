# %% [markdown]
# # Table of Contents
#  <p><div class="lev2 toc-item"><a href="#Getting-Help-&amp;-search" data-toc-modified-id="Getting-Help-&amp;-search-0.1"><span class="toc-item-num">0.1&nbsp;&nbsp;</span>Getting Help &amp; search</a></div><div class="lev3 toc-item"><a href="#help()-or-?" data-toc-modified-id="help()-or-?-0.1.1"><span class="toc-item-num">0.1.1&nbsp;&nbsp;</span><code>help()</code> or <code>?</code></a></div><div class="lev3 toc-item"><a href="#help.search()-or-??" data-toc-modified-id="help.search()-or-??-0.1.2"><span class="toc-item-num">0.1.2&nbsp;&nbsp;</span><code>help.search()</code> or <code>??</code></a></div><div class="lev3 toc-item"><a href="#apropos()" data-toc-modified-id="apropos()-0.1.3"><span class="toc-item-num">0.1.3&nbsp;&nbsp;</span><code>apropos()</code></a></div><div class="lev3 toc-item"><a href="#ls()-or-objects()" data-toc-modified-id="ls()-or-objects()-0.1.4"><span class="toc-item-num">0.1.4&nbsp;&nbsp;</span><code>ls()</code> or <code>objects()</code></a></div><div class="lev3 toc-item"><a href="#ls.str()-or-lsf.str()" data-toc-modified-id="ls.str()-or-lsf.str()-0.1.5"><span class="toc-item-num">0.1.5&nbsp;&nbsp;</span><code>ls.str()</code> or <code>lsf.str()</code></a></div><div class="lev3 toc-item"><a href="#data()--to-list-the-available-data-sets" data-toc-modified-id="data()--to-list-the-available-data-sets-0.1.6"><span class="toc-item-num">0.1.6&nbsp;&nbsp;</span><code>data()</code>  to list the available data sets</a></div><div class="lev3 toc-item"><a href="#browseVignettes()-and-vignette()" data-toc-modified-id="browseVignettes()-and-vignette()-0.1.7"><span class="toc-item-num">0.1.7&nbsp;&nbsp;</span><code>browseVignettes()</code> and <code>vignette()</code></a></div><div class="lev1 toc-item"><a href="#The-Search-List" data-toc-modified-id="The-Search-List-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>The Search List</a></div><div class="lev1 toc-item"><a href="#RSiteSearch(&quot;ggplot2&quot;)" data-toc-modified-id="RSiteSearch(&quot;ggplot2&quot;)-2"><span class="toc-item-num">2&nbsp;&nbsp;</span><code>RSiteSearch("ggplot2")</code></a></div><div class="lev1 toc-item"><a href="#Rseek---rstats-search-engine" data-toc-modified-id="Rseek---rstats-search-engine-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Rseek - rstats search engine</a></div><div class="lev1 toc-item"><a href="#library(ggplot2)-Vs-require(ggplot2)" data-toc-modified-id="library(ggplot2)-Vs-require(ggplot2)-4"><span class="toc-item-num">4&nbsp;&nbsp;</span><code>library(ggplot2)</code> Vs <code>require(ggplot2)</code></a></div>

# %% [markdown]
# ## Getting Help & search

# %% [markdown]
# ### `help()` or `?`

# %%
?print
# is same as

# %%
help(print)  # or help("plot")

# %% [markdown]
# ### `help.search()` or `??`

# %%
??plot

# %%
help.search("plot")

# %% [markdown]
# ### `apropos()`

# %%
apropos("wh")
apropos("ls")
# Out:
# [1] ".__C__while"  "argsAnywhere" "getAnywhere"  "Sys.which"    "which"
# [6] "which.max"    "which.min"    "while"
#  [1] ".__C__data.frameRowLabels" ".colSums"
#  [3] ".getXlevels"               ".signalSimpleWarning"
#  [5] "ar.ols"                    "ascentDetails"
#  [7] "co.intervals"              "colSums"
#  [9] "de.ncols"                  "densCols"
# [11] "descentDetails"            "draw.details"
# [13] "drawDetails"               "droplevels"
# [15] "droplevels.data.frame"     "droplevels.factor"
# [17] "editDetails"               "evalSource"
# [19] "formals"                   "formals<-"
# [21] "getAllSuperClasses"        "getLoadedDLLs"
# [23] "grid.ls"                   "heightDetails"
# [25] "ifelse"                    "labels"
# [27] "labels.default"            "levels"
# [29] "levels.default"            "levels<-"
# [31] "levels<-.factor"           "limitedLabels"
# [33] "ls"                        "ls.diag"
# [35] "ls.print"                  "ls.str"
# ...

# %%
apropos("qp")
?qplot
?qqplot
# Out:
# [1] "geom_freqpoly" "qplot"         "qpois"         "qqplot"

# %% [markdown]
# ### `ls()` or `objects() `

# %% [markdown]
# ```{r}
# #without loading ggplot2 package into current session (gives an error)
# ```
# `ls("package:ggplot2")`
# ```{r}
# Error in as.environment(pos): no item called "package:ggplot2" on the search list
# Traceback:
#
# 1. ls("package:ggplot2")
# ```

# %%
library(ggplot2) # loading package into current session

ls("package:ggplot2") # list out the objects present in ggplot2
# or
head(objects("package:ggplot2"))
# Out:
#   [1] "%+%"                       "%+replace%"
#   [3] "aes"                       "aes_"
#   [5] "aes_all"                   "aes_auto"
#   [7] "aes_q"                     "aes_string"
#   [9] "alpha"                     "annotate"
#  [11] "annotation_custom"         "annotation_logticks"
#  [13] "annotation_map"            "annotation_raster"
#  [15] "arrow"                     "as_labeller"
#  [17] "autoplot"                  "AxisSecondary"
#  [19] "benchplot"                 "borders"
#  [21] "calc_element"              "combine_vars"
#  [23] "continuous_scale"          "Coord"
#  [25] "coord_cartesian"           "coord_equal"
#  [27] "coord_fixed"               "coord_flip"
#  [29] "coord_map"                 "coord_munch"
#  [31] "coord_polar"               "coord_quickmap"
#  [33] "coord_trans"               "CoordCartesian"
#  [35] "CoordFixed"                "CoordFlip"
#  [37] "CoordMap"                  "CoordPolar"
#  [39] "CoordQuickmap"             "CoordTrans"
# ...

# %% [markdown]
# ### `ls.str()` or `lsf.str()`

# %%
library(ggplot2)

# %%
head(lsf.str("package:ggplot2"))
# Out:
# [1] "%+%"        "%+replace%" "aes"        "aes_"       "aes_all"
# [6] "aes_auto"

# %%
head(ls.str("package:ggplot2"))
# Out:
# [1] "%+%"        "%+replace%" "aes"        "aes_"       "aes_all"
# [6] "aes_auto"

# %% [markdown]
# ### `data()`  to list the available data sets

# %%
data() #list out all the databases on the search list

# %%
data(package="ggplot2") #list out the databases present in ggplot2 package

# %% [markdown]
# ### `browseVignettes()` and `vignette()`

# %% [markdown]
# * detailed information or important features of any topic in the form of pdf/html

# %%
browseVignettes()

# %%
library(grid)

# %%
vignette()

# %%
vignette("abcvignette")
# Out:
# Warning message:
# "vignette 'abcvignette' not found"

# %%
vignette(package = "ggplot2")

# %%
vignette("ggplot2-specs")
vignette("extending-ggplot2")

# %% [markdown]
# # The Search List

# %% [markdown]
# * R has a search list where it looks for objects. This can be changed in the course of a session

# %%
search()
# Out:
#  [1] ".GlobalEnv"        "package:grid"      "package:ggplot2"
#  [4] "package:formatR"   "jupyter:irkernel"  "package:stats"
#  [7] "package:graphics"  "package:grDevices" "package:utils"
# [10] "package:datasets"  "package:methods"   "Autoloads"
# [13] "package:base"

# %%
# Notice that the loading of a new package extends the search list.
library(ggplot2)
search()
# Out:
#  [1] ".GlobalEnv"        "package:grid"      "package:ggplot2"
#  [4] "package:formatR"   "jupyter:irkernel"  "package:stats"
#  [7] "package:graphics"  "package:grDevices" "package:utils"
# [10] "package:datasets"  "package:methods"   "Autoloads"
# [13] "package:base"

# %% [markdown]
# # `RSiteSearch("ggplot2")`
# * navigate to special R Site Search (http://search.r-project.org) with this package name(ggplot2)

# %%
RSiteSearch("ggplot2")
# Out:
# A search query has been submitted to http://search.r-project.org
# The results page should open in your browser shortly

# %% [markdown]
# # Rseek - rstats search engine

# %% [markdown]
# * google search like feature for specifically R users
#
# https://rseek.org/
